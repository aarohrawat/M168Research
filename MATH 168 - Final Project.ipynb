# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # Artists

# %%
artists = nx.read_edgelist("/Users/ryanquach/Downloads/artist_edges.csv",
                           delimiter = ",", nodetype = str)
deg_dist_art = [artists.degree(n) for n in artists.nodes()]

# %%
plt.hist(deg_dist_art, bins = 100)
plt.title("Artists - Degree Distribution")
plt.xlabel("Degree")
plt.ylabel("Number of nodes");

# %%
round(stats.skew(deg_dist_art), 3)
# Out:
# 7.402

# %%
round(nx.average_clustering(artists), 3)
# Out:
# 0.138

# %% [markdown]
# # Athletes

# %%
athletes = nx.read_edgelist("/Users/ryanquach/Downloads/athletes_edges.csv",
                            delimiter = ",", nodetype = str)
deg_dist_ath = [athletes.degree(n) for n in athletes.nodes()]

# %%
plt.hist(deg_dist_ath, bins = 100)
plt.title("Athletes - Degree Distribution")
plt.xlabel("Degree")
plt.ylabel("Number of nodes");

# %%
round(stats.skew(deg_dist_ath), 3)
# Out:
# 6.536

# %%
round(nx.average_clustering(athletes), 3)
# Out:
# 0.276

# %% [markdown]
# # Companies

# %%
companies = nx.read_edgelist("/Users/ryanquach/Downloads/company_edges.csv",
                             delimiter = ",", nodetype = str)
deg_dist_company = [companies.degree(n) for n in companies.nodes()]

# %%
plt.hist(deg_dist_company, bins = 100)
plt.title("Companies - Degree Distribution")
plt.xlabel("Degree")
plt.ylabel("Number of nodes");

# %%
round(stats.skew(deg_dist_company), 3)
# Out:
# 6.414

# %%
round(nx.average_clustering(companies), 3)
# Out:
# 0.239

# %% [markdown]
# # Government

# %%
gov = nx.read_edgelist("/Users/ryanquach/Downloads/government_edges.csv",
                       delimiter = ",", nodetype = str)
deg_dist_gov = [gov.degree(n) for n in gov.nodes()]

# %%
plt.hist(deg_dist_gov, bins = 100)
plt.title("Government - Degree Distribution")
plt.xlabel("Degree")
plt.ylabel("Number of nodes");

# %%
round(stats.skew(deg_dist_gov), 3)
# Out:
# 6.016

# %%
round(nx.average_clustering(gov), 3)
# Out:
# 0.411

# %% [markdown]
# # News

# %%
news = nx.read_edgelist("/Users/ryanquach/Downloads/new_sites_edges.csv",
                        delimiter = ",", nodetype = str)
deg_dist_news = [news.degree(n) for n in news.nodes()]

# %%
plt.hist(deg_dist_news, bins = 100)
plt.title("News Sites - Degree Distribution")
plt.xlabel("Degree")
plt.ylabel("Number of nodes");

# %%
round(stats.skew(deg_dist_news), 3)
# Out:
# 8.829

# %%
round(nx.average_clustering(news), 3)
# Out:
# 0.295

# %% [markdown]
# # Politicians

# %%
pol = nx.read_edgelist("/Users/ryanquach/Downloads/politician_edges.csv",
                       delimiter = ",", nodetype = str)
deg_dist_pol = [pol.degree(n) for n in pol.nodes()]

# %%
plt.hist(deg_dist_pol, bins = 100)
plt.title("Politicians - Degree Distribution")
plt.xlabel("Degree")
plt.ylabel("Number of nodes");

# %%
round(stats.skew(deg_dist_pol), 3)
# Out:
# 4.462

# %%
round(nx.average_clustering(pol), 3)
# Out:
# 0.385

# %% [markdown]
# # Public Figures

# %%
pubfig = nx.read_edgelist("/Users/ryanquach/Downloads/public_figure_edges.csv",
                          delimiter = ",", nodetype = str)
deg_dist_pubfig = [pubfig.degree(n) for n in pubfig.nodes()]

# %%
plt.hist(deg_dist_pubfig, bins = 100)
plt.title("Public Figures - Degree Distribution")
plt.xlabel("Degree")
plt.ylabel("Number of nodes");

# %%
round(stats.skew(deg_dist_pubfig), 3)
# Out:
# 5.403

# %%
round(nx.average_clustering(pubfig), 3)
# Out:
# 0.179

# %% [markdown]
# # TV Shows

# %%
TV = nx.read_edgelist("/Users/ryanquach/Downloads/tvshow_edges.csv",
                      delimiter = ",", nodetype = str)
deg_dist_TV = [TV.degree(n) for n in TV.nodes()]

# %%
plt.hist(deg_dist_TV, bins = 100)
plt.title("TV Shows - Degree Distribution")
plt.xlabel("Degree")
plt.ylabel("Number of nodes");

# %%
round(stats.skew(deg_dist_TV), 3)
# Out:
# 3.713

# %%
round(nx.average_clustering(TV), 3)
# Out:
# 0.374
